# %%
import pandas as pd
import numpy as np

tv = pd.read_csv(r'../input/tv-series-dataset/series_data.csv')
#tv.drop_duplicates(subset = ['Series_Title'], keep = 'last', inplace = True)
tv.head(10)
# Out:
#                                          Poster_Link           Series_Title  \
# 0  https://m.media-amazon.com/images/M/MV5BYTRiND...        Game of Thrones
# 1  https://m.media-amazon.com/images/M/MV5BMjhiMz...           Breaking Bad
# 2  https://m.media-amazon.com/images/M/MV5BMTc5Zm...       The Walking Dead
# 3  https://m.media-amazon.com/images/M/MV5BNDVkYj...                Friends
# 4  https://m.media-amazon.com/images/M/MV5BMjEzMD...        Stranger Things
# 5  https://m.media-amazon.com/images/M/MV5BMWY3NT...               Sherlock
# 6  https://m.media-amazon.com/images/M/MV5BY2FmZT...    The Big Bang Theory
# 7  https://m.media-amazon.com/images/M/MV5BMTM5Mj...                 Dexter
# 8  https://m.media-amazon.com/images/M/MV5BNjg1MD...  How I Met Your Mother
# 9  https://m.media-amazon.com/images/M/MV5BMTUwMG...         True Detective
#
#   Runtime_of_Series Certificate Runtime_of_Episodes                     Genre  \
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words = 'english')

vectorized = tfidf.fit_transform(tv['Overview'])

vectorized.shape
# Out:
# (2000, 8089)

# %%
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

sim = linear_kernel(vectorized, vectorized)

indices = pd.Series(tv.index, index = tv['Series_Title']).drop_duplicates()

# %%
def get_recommendations(title, sim = sim):
    
    idx = indices[title]
    print(idx)
    
    sim_scores = list(enumerate(sim[idx]))
    #print(sim_scores)
    
   
    sim_scores = sorted(sim_scores, key = lambda x : x[1], reverse = True)
    
    sim_scores = sim_scores[1 : 16]
    
    series_indices = [i[0] for i in sim_scores]
    
    return tv['Series_Title'].iloc[series_indices], sim_scores

# %%
get_recommendations('Supergirl')
# Out:
# 138
# (926                                          Krypton
#  1669                               Avengers Assemble
#  682     Lois & Clark: The New Adventures of Superman
#  1635                                    Frisky Dingo
#  75                                     Jessica Jones
#  1384                               Perfect Strangers
#  1202                                       The Catch
#  487                                          Rugrats
#  920                                    Darkwing Duck
#  836                         The Adventures of Tintin
#  1181                 Harvey Birdman, Attorney at Law
#  1767                      Space Ghost Coast to Coast
#  674                                  Black Lightning
#  559                                       Spider-Man
#  1358                                        The Tick
#  Name: Series_Title, dtype: object,
#  [(926, 0.22373796905187746),
#   (1669, 0.2062025773873734),
#   (682, 0.19071209386200164),
# ...
